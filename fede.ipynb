# %%
import pandas as pd

# %%
import numpy as np
df = pd.read_csv('columbia_full.csv')
df.columns
# Out:
# Index(['FechaPlanInicioTransporte', 'RegionalDistribucion', 'IDCentro',
#        'CodigoCliente', 'DocumentoTransporte', 'Ordered_vol', 'ordered_boxes',
#        'Plan_Vol', 'plan_boxes'],
#       dtype='object')

# %%
unique_id_centro = df['RegionalDistribucion'].unique()
print(unique_id_centro)
# Out:
# ['Sur' 'Centro' 'Norte' 'Andes']

# %%
unique_counts = df.groupby('RegionalDistribucion').nunique()
unique_counts
# Out:
#                       FechaPlanInicioTransporte  IDCentro  CodigoCliente  \
# RegionalDistribucion
# Andes                                        31        14          47072
# Centro                                       31        14          71794
# Norte                                        30        20          53072
# Sur                                          30        16          45410
#
#                       DocumentoTransporte  Ordered_vol  ordered_boxes  \
# RegionalDistribucion
# Andes                               11064        55081           8316
# Centro                              15492        55706           9849
# Norte                               13517        69806           8839
# Sur                                  9717        49119           8586
#
#                       Plan_Vol  plan_boxes
# RegionalDistribucion
# Andes                    55087        8352
# Centro                   55730        9884
# Norte                    69856        8869
# ...

# %%
df_centro = df[df['RegionalDistribucion'] == 'Centro']
df_centro.head
# Out:
# <bound method NDFrame.head of        FechaPlanInicioTransporte RegionalDistribucion IDCentro  CodigoCliente  \
# 1                     2025-03-01               Centro     AV47       12307950
# 2                     2025-03-06               Centro     AV26       13212774
# 8                     2025-03-12               Centro     AV04       11413970
# 14                    2025-03-31               Centro     AV04       10287272
# 15                    2025-03-20               Centro     AV47       10766132
# ...                          ...                  ...      ...            ...
# 523246                2025-03-28               Centro     AV53       11036679
# 523248                2025-03-26               Centro     AV53       10768166
# 523249                2025-03-19               Centro     AV78       10741070
# 523251                2025-03-20               Centro     AV47       10640224
# 523253                2025-03-12               Centro     AV06       14208244
#
# ...

# %%
df_centro['FechaPlanInicioTransporte'] = pd.to_datetime(df_centro['FechaPlanInicioTransporte'])
df_centro = df_centro.sort_values(by='FechaPlanInicioTransporte')
df_centro.head
# Out:
# /var/folders/f5/kfhjr6d55t3f6fpgzj_trt340000gn/T/ipykernel_870/2289736522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_centro['FechaPlanInicioTransporte'] = pd.to_datetime(df_centro['FechaPlanInicioTransporte'])
# <bound method NDFrame.head of        FechaPlanInicioTransporte RegionalDistribucion IDCentro  CodigoCliente  \
# 1                     2025-03-01               Centro     AV47       12307950
# 278831                2025-03-01               Centro     AV66       11180353
# 278771                2025-03-01               Centro     AV53       13179480
# 26769                 2025-03-01               Centro     AV66       14184754
# 278490                2025-03-01               Centro     AV26       14294025
# ...

# %%
df_day1 = df_centro[df_centro['FechaPlanInicioTransporte'] == '2025-03-01']

# %%
df_day1
# Out:
#        FechaPlanInicioTransporte RegionalDistribucion IDCentro  CodigoCliente  \
# 1                     2025-03-01               Centro     AV47       12307950
# 278831                2025-03-01               Centro     AV66       11180353
# 278771                2025-03-01               Centro     AV53       13179480
# 26769                 2025-03-01               Centro     AV66       14184754
# 278490                2025-03-01               Centro     AV26       14294025
# ...                          ...                  ...      ...            ...
# 501765                2025-03-01               Centro     AV66       11322068
# 2439                  2025-03-01               Centro     AV04       12590410
# 500426                2025-03-01               Centro     AV04       12410026
# 404558                2025-03-01               Centro     AV78       12532917
# 502637                2025-03-01               Centro     AV53       11508741
#
# ...

# %%
unique_centres = df_day1.groupby('RegionalDistribucion').nunique()
unique_centres
# Out:
#                       FechaPlanInicioTransporte  IDCentro  CodigoCliente  \
# RegionalDistribucion
# Centro                                        1        12           6597
#
#                       DocumentoTransporte  Ordered_vol  ordered_boxes  \
# RegionalDistribucion
# Centro                                526         3993           1117
#
#                       Plan_Vol  plan_boxes
# RegionalDistribucion
# Centro                    3994        1118

# %%
random_customers = df_day1.sample(n=100, random_state=42)
random_customers
# Out:
#        FechaPlanInicioTransporte RegionalDistribucion IDCentro  CodigoCliente  \
# 249013                2025-03-01               Centro     AV06       13233818
# 446187                2025-03-01               Centro     AV78       10623093
# 421424                2025-03-01               Centro     AV04       12735977
# 72748                 2025-03-01               Centro     AV50       12569661
# 512335                2025-03-01               Centro     AV53       13685327
# ...                          ...                  ...      ...            ...
# 146401                2025-03-01               Centro     AV06       12287346
# 313773                2025-03-01               Centro     AV06       12632084
# 48934                 2025-03-01               Centro     AV26       10750667
# 153111                2025-03-01               Centro     AV66       11268772
# 382929                2025-03-01               Centro     AV26       14031188
#
# ...

# %%
filepath = 'https://github.com/Amelie-Mad/logistics'
coord_centro = pd.read_csv(filepath + 'CoordenadasCDs.csv')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# ...
