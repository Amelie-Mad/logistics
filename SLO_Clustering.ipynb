# %% [markdown]
# <a href="https://colab.research.google.com/github/Amelie-Mad/logistics/blob/main/SLO_Clustering_Felix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import time

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Amelie-Mad/logistics/refs/heads/main/columbia_full_coordinates.csv')

# %%
df['ordered_volume'].sum()
# Out:
# np.float64(1032486.6900407146)

# %%
unique_client_count = df['Client_ID'].nunique()
print(f"Number of unique client IDs: {unique_client_count}")
# Out:
# Number of unique client IDs: 171818

# %%
df['region'].unique()
# Out:
# array(['Sur', 'Centro', 'Norte', 'Andes'], dtype=object)

# %%
df['Center_ID'].unique()
# Out:
# array(['AV46', 'AV47', 'AV26', 'AV39', 'AV18', 'AV04', 'AV22', 'AV52',
#        'AV40', 'AV05', 'AV38', 'AV12', 'AV06', 'AV50', 'AV37', 'AV20',
#        'AV17', 'AV42', 'AV02', 'AV11', 'AV34', 'AV10', 'AV55', 'AV16',
#        'AV15', 'AV19', 'AV35', 'AV13', 'AV30', 'AV24', 'AV27', 'AV29',
#        'AV01', 'AV25', 'AV28', 'AV32', 'AV33', 'AV36', 'AV03'],
#       dtype=object)

# %%
# Create a new DataFrame with unique distribution centers
unique_centers = df.drop_duplicates(subset=['Center_ID'])

# Select relevant columns
distribution_centers_df = unique_centers[['Center_ID', 'region', 'Longitude_CD', 'Latitude_CD']]

# Display the resulting DataFrame
distribution_centers_df
# Out:
#       Center_ID  region  Longitude_CD  Latitude_CD
# 0          AV46     Sur    -76.492858     3.535408
# 1          AV47  Centro    -74.251706     4.541264
# 2          AV26  Centro    -74.148856     4.596453
# 3          AV39   Norte    -75.847328     8.729500
# 4          AV18     Sur    -75.285719     2.915592
# 5          AV04  Centro    -73.006556     5.807142
# 6          AV22   Andes    -75.709200     4.476094
# 7          AV52   Andes    -75.559508     6.283450
# 8          AV40   Norte    -75.202828     7.975614
# 9          AV05   Andes    -75.618514     6.168617
# 12         AV38   Norte    -73.544011     9.199086
# 13         AV12   Norte    -73.242439    10.447183
# 14         AV06  Centro    -73.941175     4.946467
# 15         AV50  Centro    -74.164592     4.742992
# 16         AV37   Andes    -73.828978     7.041967
# 17         AV20   Norte    -72.463717     7.908339
# 20         AV17     Sur    -74.798261     4.301378
# 23         AV42  Centro    -73.352553     5.544456
# 28         AV02   Andes    -73.138314     7.162578
# 29         AV11   Norte    -74.164217    11.225206
# 30         AV34   Andes    -73.639067     5.909672
# 31         AV10   Norte    -75.463156    10.374478
# 36         AV55   Andes    -75.447800     6.388700
# 38         AV16   Andes    -75.832822     4.802644
# 58         AV15     Sur    -77.305711     1.154189
# 59         AV19     Sur    -73.635186     4.115817
# 62         AV35   Andes    -73.151278     6.555942
# 69         AV13   Norte    -75.335433     9.315136
# 71         AV30   Norte    -72.945150    11.522925
# 96         AV24     Sur    -72.427817     5.280189
# 99         AV27     Sur    -75.180797     4.415833
# 111        AV29   Norte    -81.701400    12.581783
# 135        AV01     Sur    -76.492861     3.535411
# 150        AV25     Sur    -74.739747     5.205206
# 157        AV28     Sur    -76.559825     2.502414
# 187        AV32   Norte    -74.742989     9.238381
# 246        AV33   Andes    -73.617231     8.298858
# 496        AV36   Norte    -72.862917    10.889917
# 13238      AV03   Norte    -74.771936    10.974686

# %%
distribution_centers_df.count()
# Out:
# Center_ID       39
# region          39
# Longitude_CD    39
# Latitude_CD     39
# dtype: int64

# %%
import folium
from folium.plugins import MarkerCluster

# Create a map centered on Colombia
m = folium.Map(location=[4.7110, -74.0721], zoom_start=6)

# Define a color palette for regions
region_colors = {
    'Sur': 'red',
    'Centro': 'blue',
    'Andes': 'green',
    'Norte': 'purple',
    'Region 5': 'orange',
    # Add more regions and colors as needed
}

# Add markers for each distribution center
for index, row in distribution_centers_df.iterrows():
    region = row['region']
    color = region_colors.get(region, 'gray')  # Default to gray if region not in palette
    folium.Marker(
        location=[row['Latitude_CD'], row['Longitude_CD']],
        popup=f"Center ID: {row['Center_ID']}, Region: {region}",
        icon=folium.Icon(color=color),
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f18b2d34ac193c8296fec8cbf09896d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f18b2d34ac193c8296fec8cbf09896d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f18b2d34ac193c8296fec8cbf09896d1 = L.map(
#                 &quot;map_f18b2d34ac193c8296fec8cbf09896d1&quot;,
#                 {
#                     center: [4.711, -74.0721],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2490044a2daaa083fb3fc029c2b409b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2490044a2daaa083fb3fc029c2b409b.addTo(map_f18b2d34ac193c8296fec8cbf09896d1);
#
#
#             var marker_cfb5df02d00aeed7f9f9f7ae981f6b3b = L.marker(
#                 [3.535408, -76.492858],
#                 {
# }
#             ).addTo(map_f18b2d34ac193c8296fec8cbf09896d1);
#
#
#             var icon_e56005aefc638c01a6db82f6a9bc314a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6bfa4ec53a7e3b160cfa820d38162ecf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_742d7d8fff445d3c1023145a25c71f55 = $(`&lt;div id=&quot;html_742d7d8fff445d3c1023145a25c71f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center ID: AV46, Region: Sur&lt;/div&gt;`)[0];
#                 popup_6bfa4ec53a7e3b160cfa820d38162ecf.setContent(html_742d7d8fff445d3c1023145a25c71f55);
#
#
#
#         marker_cfb5df02d00aeed7f9f9f7ae981f6b3b.bindPopup(popup_6bfa4ec53a7e3b160cfa820d38162ecf)
#         ;
#
#
#
#
#                 marker_cfb5df02d00aeed7f9f9f7ae981f6b3b.setIcon(icon_e56005aefc638c01a6db82f6a9bc314a);
#
#
#             var marker_d0de18d15e46e67ce52ac72c0fac01ab = L.marker(
#                 [4.541264, -74.251706],
#                 {
# }
#             ).addTo(map_f18b2d34ac193c8296fec8cbf09896d1);
#
#
#             var icon_a75359cfea4ff52e90e38b9790c84943 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a8dc0fc0e3409ac362f13baad2026625 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be215fcc0c4a658f1ea5c6b3fa7c7d35 = $(`&lt;div id=&quot;html_be215fcc0c4a658f1ea5c6b3fa7c7d35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center ID: AV47, Region: Centro&lt;/div&gt;`)[0];
#                 popup_a8dc0fc0e3409ac362f13baad2026625.setContent(html_be215fcc0c4a658f1ea5c6b3fa7c7d35);
#
#
#
#         marker_d0de18d15e46e67ce52ac72c0fac01ab.bindPopup(popup_a8dc0fc0e3409ac362f13baad2026625)
#         ;
#
#
#
#
#                 marker_d0de18d15e46e67ce52ac72c0fac01ab.setIcon(icon_a75359cfea4ff52e90e38b9790c84943);
#
#
#             var marker_23cf6e5ebe680ba79f505c9db976db9e = L.marker(
#                 [4.596453, -74.148856],
#                 {
# }
#             ).addTo(map_f18b2d34ac193c8296fec8cbf09896d1);
#
#
#             var icon_6f556b6c6cd34397080944861ecb729f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8050a14dae1354316a3d31750d769e61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f9dac3fd78d2d9e695254e1b2ce3e3d = $(`&lt;div id=&quot;html_7f9dac3fd78d2d9e695254e1b2ce3e3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center ID: AV26, Region: Centro&lt;/div&gt;`)[0];
#                 popup_8050a14dae1354316a3d31750d769e61.setContent(html_7f9dac3fd78d2d9e695254e1b2ce3e3d);
#
#
#
#         marker_23cf6e5ebe680ba79f505c9db976db9e.bindPopup(popup_8050a14dae1354316a3d31750d769e61)
#         ;
#
#
#
#
#                 marker_23cf6e5ebe680ba79f505c9db976db9e.setIcon(icon_6f556b6c6cd34397080944861ecb729f);
#
#
#             var marker_65a95d45a09e6721c2ed6fa538687efc = L.marker(
#                 [8.7295, -75.847328],
#                 {
# }
#             ).addTo(map_f18b2d34ac193c8296fec8cbf09896d1);
#
#
#             var icon_871e39218afe9f0

# %%
df
# Out:
#               date  region Center_ID  Client_ID  ordered_boxes  Latitude_CD  \
# 0       2025-03-18     Sur      AV46   11645498          50.00     3.535408
# 1       2025-03-01  Centro      AV47   12307950          12.02     4.541264
# 2       2025-03-06  Centro      AV26   13212774           2.00     4.596453
# 3       2025-03-31   Norte      AV39   12946586         102.25     8.729500
# 4       2025-03-20     Sur      AV18   13682698           6.00     2.915592
# ...            ...     ...       ...        ...            ...          ...
# 406924  2025-03-20  Centro      AV47   10640224           8.50     4.541264
# 406925  2025-03-15   Andes      AV05   14260184           5.75     6.168617
# 406926  2025-03-12  Centro      AV06   14208244          32.00     4.946467
# 406927  2025-03-18     Sur      AV24   12610824          19.52     5.280189
# 406928  2025-03-29     Sur      AV15   13165100          52.75     1.154189
#
#         Longitude_CD  Latitude_Client  Longitude_Client  ordered_volume
# 0         -76.492858         3.449400        -76.522300        3.780000
# 1         -74.251706         4.562510        -74.236074        0.908712
# 2         -74.148856         4.563009        -74.104803        0.151200
# 3         -75.847328         8.953745        -75.838556        7.730100
# 4         -75.285719         2.924496        -75.259561        0.453600
# ...              ...              ...               ...             ...
# 406924    -74.251706         4.615580        -74.351343        0.642600
# 406925    -75.618514         6.171558        -75.610056        0.434700
# 406926    -73.941175         4.908358        -73.942483        2.419200
# 406927    -72.427817         5.181973        -72.572259        1.475712
# 406928    -77.305711         1.130100        -77.548000        3.987900
#
# [406929 rows x 10 columns]

# %%
# Create a new DataFrame with unique clients
unique_clients_df = df.drop_duplicates(subset=['Client_ID'])

# Select relevant columns (customize as needed)
unique_clients_df = unique_clients_df[['Client_ID', 'region', 'Longitude_Client', 'Latitude_Client']]

# Display the resulting DataFrame
unique_clients_df
# Out:
#         Client_ID  region  Longitude_Client  Latitude_Client
# 0        11645498     Sur        -76.522300         3.449400
# 1        12307950  Centro        -74.236074         4.562510
# 2        13212774  Centro        -74.104803         4.563009
# 3        12946586   Norte        -75.838556         8.953745
# 4        13682698     Sur        -75.259561         2.924496
# ...           ...     ...               ...              ...
# 406897   12454670     Sur        -76.679047         2.352239
# 406912   12168313     Sur        -76.638772         3.589321
# 406913   10742803  Centro        -74.107000         4.585720
# 406918   13185779  Centro        -74.116000         4.506860
# 406927   12610824     Sur        -72.572259         5.181973
#
# [171818 rows x 4 columns]

# %%
# Create a map centered on Colombia
m = folium.Map(location=[4.7110, -74.0721], zoom_start=6)

# Add markers for each unique client
marker_cluster = MarkerCluster().add_to(m) # Use MarkerCluster for performance

for index, row in unique_clients_df.iterrows():
    folium.Marker(
        location=[row['Latitude_Client'], row['Longitude_Client']],
        popup=f"Client ID: {row['Client_ID']}",
    ).add_to(marker_cluster)

# Display the map
m

# %%
fig = px.scatter_mapbox(unique_clients_df,
                        lat="Latitude_Client",
                        lon="Longitude_Client",
                        color="region",
                        zoom=8,
                        height=600,
                        width=800,
                        mapbox_style="carto-positron")

fig.show()

# %%
import folium
from folium.plugins import MarkerCluster
from tqdm import tqdm

# Create a map centered on Colombia
m = folium.Map(location=[4.7110, -74.0721], zoom_start=6)

# Define a color palette for regions (for distribution centers)
region_colors = {
    'Sur': 'red',
    'Centro': 'blue',
    'Andes': 'green',
    'Norte': 'purple',
    'Region 5': 'orange',
    # Add more regions and colors as needed
}

# Add markers for each distribution center
for index, row in distribution_centers_df.iterrows():
    region = row['region']
    color = region_colors.get(region, 'gray')  # Default to gray if region not in palette
    folium.Marker(
        location=[row['Latitude_CD'], row['Longitude_CD']],
        popup=f"Center ID: {row['Center_ID']}, Region: {region}",
        icon=folium.Icon(color=color, icon='home'),  # Added home icon for distribution centers
    ).add_to(m)

# Add markers for each client (assuming your DataFrame with clients is called 'df')
for index, row in unique_clients_df.iterrows():
    folium.CircleMarker(
        location=[row['Latitude_Client'], row['Longitude_Client']],
        radius=3,  # Adjust the radius as needed
        popup=f"Client ID: {row['Client_ID']}",
        color='black',  # Set a color for clients
        fill=True,
        fill_color='black',
        fill_opacity=0.6
    ).add_to(m)

# Display the map
m

# %%
df_centro = df[df['region'] == 'Centro']
df_centro

# %%
duplicate_client_ids = df_centro[df_centro.duplicated(subset=['Client_ID'], keep=False)]

if not duplicate_client_ids.empty:
  print("Duplicate Client_IDs found:")
  print(duplicate_client_ids['Client_ID'])
else:
  print("No duplicate Client_IDs found.")

# %%
grouped_df = df_centro.groupby('Client_ID').agg(
    ordered_boxes=('ordered_boxes', 'sum'),
    ordered_volume=('ordered_volume', 'sum')
).reset_index()

# Merge the aggregated data back to the original DataFrame
df_centro = pd.merge(grouped_df, df_centro.drop_duplicates(subset='Client_ID').drop(['ordered_boxes', 'ordered_volume'], axis=1), on='Client_ID', how='left')
df_centro

# %%
# Assuming df_centro is your DataFrame
clients = df_centro[['Client_ID', 'Latitude_Client', 'Longitude_Client']]
centers = df_centro[['Center_ID', 'Latitude_CD', 'Longitude_CD']].drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Solve assignment of clients based on Clustering

# %%
# Cell 1: Perform Clustering


def calculate_clusters(df_centro, n_clusters=100):
    """Cluster clients into geographical groups"""
    print(f"Clustering {len(df_centro)} clients into {n_clusters} groups...")
    start_time = time.time()

    # Extract client coordinates
    client_coords = np.array(list(zip(
        df_centro['Latitude_Client'],
        df_centro['Longitude_Client']
    )))

    # Perform K-means clustering
    kmeans = KMeans(
        n_clusters=n_clusters,
        random_state=42,
        n_init=10
    ).fit(client_coords)

    # Add cluster IDs to DataFrame
    df_centro['cluster_id'] = kmeans.labels_

    # Calculate execution time
    duration = time.time() - start_time
    print(f"Clustering completed in {duration:.1f} seconds")
    print(f"Cluster sizes:\n{df_centro['cluster_id'].value_counts().describe()}")

    return df_centro

# Execute clustering
try:
    df_centro = calculate_clusters(df_centro)
except Exception as e:
    print(f"Clustering failed: {str(e)}")
    raise

# %%
# !pip install plotly

import plotly.express as px

# Assuming df_centro has 'Latitude_Client', 'Longitude_Client', and 'cluster_id' columns
fig = px.scatter_mapbox(df_centro,
                        lat="Latitude_Client",
                        lon="Longitude_Client",
                        color="cluster_id",
                        zoom=8,
                        height=600,
                        width=800,
                        mapbox_style="carto-positron") # or open-street-map, stamen-terrain, etc.

# 2. Add the distribution centers as a new trace
fig.add_trace(px.scatter_mapbox(centers,
                                 lat="Latitude_CD",
                                 lon="Longitude_CD",
                                 color_discrete_sequence=["red"],  # Highlight in red
                                 hover_data=['Center_ID'],  # Show Center_ID on hover
                                 size_max=30  # Changed 'size' to 'size_max'
                                ).data[0])  # Adjust size for visibility

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
# Cell 2: Calculate Cluster Centroids
def calculate_centroids(df_centro):
    """Calculate geographic centroids for each cluster"""
    print("\nCalculating cluster centroids...")
    start_time = time.time()

    n_clusters = df_centro['cluster_id'].nunique()
    centroids = []

    for cluster_id in range(n_clusters):
        cluster_df = df_centro[df_centro['cluster_id'] == cluster_id]

        if len(cluster_df) == 0:
            raise ValueError(f"Cluster {cluster_id} is empty")

        centroid = (
            cluster_df['Latitude_Client'].mean(),
            cluster_df['Longitude_Client'].mean()
        )
        centroids.append(centroid)

    # Add centroids to a DataFrame
    centroids_df = pd.DataFrame(centroids, columns=['Latitude', 'Longitude'])
    centroids_df['cluster_id'] = range(n_clusters)

    duration = time.time() - start_time
    print(f"Calculated {len(centroids)} centroids in {duration:.1f} seconds")

    return centroids_df

# Execute centroid calculation
try:
    centroids_df = calculate_centroids(df_centro)
except Exception as e:
    print(f"Centroid calculation failed: {str(e)}")
    raise

# %%
# Cell 3: Assign Clusters to DCs via API
import requests
from tqdm import tqdm

def assign_clusters_to_dcs(centroids_df, df_centro):
    """Assign clusters to distribution centers using OSRM API"""
    print("\nStarting DC assignment process...")
    start_time = time.time()

    # Get DC coordinates
    centers = df_centro[['Center_ID', 'Latitude_CD', 'Longitude_CD']].drop_duplicates()
    dc_coords = list(zip(centers['Latitude_CD'], centers['Longitude_CD']))
    dc_ids = centers['Center_ID'].tolist()

    # Storage for assignments
    cluster_assignments = {}
    distance_matrix = []

    try:
        # Process each cluster with progress bar
        for idx, row in tqdm(centroids_df.iterrows(), total=len(centroids_df), desc="API Progress"):
            centroid = (row['Latitude'], row['Longitude'])
            distances = []

            for dc in dc_coords:
                url = f"https://router.project-osrm.org/route/v1/driving/" \
                      f"{centroid[1]},{centroid[0]};{dc[1]},{dc[0]}?overview=false"

                response = requests.get(url, timeout=60)
                response.raise_for_status()

                data = response.json()
                distances.append(data['routes'][0]['distance'] / 1000)  # Convert to km

                # Rate limiting
                time.sleep(0.1)

            # Find closest DC
            closest_dc_idx = np.argmin(distances)
            cluster_assignments[row['cluster_id']] = dc_ids[closest_dc_idx]
            distance_matrix.append(distances)

    except Exception as e:
        print(f"\nAPI call failed at cluster {row['cluster_id']}")
        print(f"Error: {str(e)}")
        raise

    # Assign final DCs to clients
    df_centro['Assigned_CD'] = df_centro['cluster_id'].map(cluster_assignments)

    # Add results to centroids DataFrame
    centroids_df['Assigned_DC'] = centroids_df['cluster_id'].map(cluster_assignments)
    centroids_df['Distances'] = distance_matrix

    duration = time.time() - start_time
    print(f"\nAssignment completed in {duration:.1f} seconds")
    print("Sample assignments:")
    print(centroids_df[['cluster_id', 'Assigned_DC']].head())

    return df_centro, centroids_df

# Execute assignment
try:
    df_centro, centroids_df = assign_clusters_to_dcs(centroids_df, df_centro)
except Exception as e:
    print(f"Assignment failed: {str(e)}")
    raise

# %%
# Display the clients and their assigned distribution centers
print(df_centro[['Client_ID', 'Assigned_CD']])

# %%
# Check for differences in assignment between 'Assigned_CD' and 'Center_ID'
differences = df_centro[df_centro['Assigned_CD'] != df_centro['Center_ID']]

if not differences.empty:
    print("Clients with different assignments:")
    print(differences[['Client_ID', 'Center_ID', 'Assigned_CD']])
else:
    print("No clients have different assignments between 'Assigned_CD' and 'Center_ID'.")

# %%
# Check for differences in assignment between 'Assigned_CD' and 'Center_ID'
differences = df_centro[df_centro['Assigned_CD'] != df_centro['Center_ID']]

if not differences.empty:
    print("Clients with different assignments:")
    print(differences[['Client_ID', 'Center_ID', 'Assigned_CD', 'Latitude_Client', 'Longitude_Client']])  # Added Latitude_Client and Longitude_Client
else:
    print("No clients have different assignments between 'Assigned_CD' and 'Center_ID'.")

# %%
# prompt: can you somehow visualize the clients which are now assigned in a different way than before?

import plotly.express as px

# Assuming df_centro has 'Latitude_Client', 'Longitude_Client', and 'Assigned_CD' columns
fig = px.scatter_mapbox(differences,
                        lat="Latitude_Client",
                        lon="Longitude_Client",
                        color="Assigned_CD",
                        zoom=8,
                        height=600,
                        width=800,
                        mapbox_style="carto-positron",
                        hover_data=['Client_ID'])

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

# Add distribution centers to the map
fig.add_trace(px.scatter_mapbox(centers,
                                lat="Latitude_CD",
                                lon="Longitude_CD",
                                color_discrete_sequence=["red"],
                                hover_data=['Center_ID'],
                                size_max=15
                               ).data[0])

fig.show()
